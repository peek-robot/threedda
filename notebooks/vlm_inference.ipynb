# %%
import numpy as np
from PIL import Image

rgb = np.array(Image.open("/gscratch/weirdlab/memmelma/problem_reduction/videoframe_0.png").convert("RGB"))
lang_instr = "put the green cube on the red cube"

# rgb = np.array(Image.open("/gscratch/weirdlab/memmelma/problem_reduction/breakfast.jpg").convert("RGB"))
# lang_instr = "pick up the sausage"

model_name = "hamster_13b"
server_ip = "http://localhost:6666"

from problem_reduction.vila.inference_hamster import hamster_inference_api
pred_img, points = hamster_inference_api(rgb, lang_instr, model_name, server_ip, prompt_type="hamster")
points
# Out:
# [[0.48, 0.65, 0], [0.37, 0.48, 0], [0.38, 0.55, 1]]

# %%
import numpy as np
from PIL import Image

rgb = np.array(Image.open("/gscratch/weirdlab/memmelma/problem_reduction/videoframe_0.png").convert("RGB"))
lang_instr = "put the green cube on the red cube"

# rgb = np.array(Image.open("/gscratch/weirdlab/memmelma/problem_reduction/breakfast.jpg").convert("RGB"))
# lang_instr = "pick up the sausage"

model_name = "vila_3b_path_mask_fast"
server_ip = "http://localhost:6666"

from problem_reduction.vila.inference_helpers import vila_inference_api
pred_img, points = vila_inference_api(rgb, lang_instr, model_name, server_ip, prompt_type="path_mask")
points
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /mmfs1/gscratch/weirdlab/memmelma/miniforge3/envs/vila/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File /mmfs1/gscratch/weirdlab/memmelma/miniforge3/envs/vila/lib/python3.10/site-packages/httpcore/_backends/sync.py:28, in SyncStream.read(self, max_bytes, timeout)
#      27 self._sock.settimeout(timeout)
# ---> 28 return self._sock.recv(max_bytes)
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ReadError                                 Traceback (most recent call last)
# ...

# %%
from problem_reduction.vila.inference_hamster import process_answer, draw_lines_on_image_cv, annotate_image
Image.fromarray(draw_lines_on_image_cv(rgb.copy(), points, draw_action=True))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
width, height, _ = rgb.shape
min(min(width, height) / 256.0, 1)
# Out:
# 0.5

# %%
import matplotlib.pyplot as plt

plt.imshow(pred_img)
