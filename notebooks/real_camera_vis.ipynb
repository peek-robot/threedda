# %%
from fs2r.perception.zed import gather_zed_cameras

zed_cameras = gather_zed_cameras(left_rgb=True, right_rgb=True)

# %%
from PIL import Image
rgb = zed_cameras[0].read_camera()["rgb"]
Image.fromarray(rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
